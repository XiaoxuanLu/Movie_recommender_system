# %% [markdown]
# # Visualizing the data

# %% [markdown]
# Before applying the content-based filtering in order to make recommendations it is important to visualize the data in order to help with later decisions on the usability of different categories.

# %%
# Ideas for data visualization:
# Visualize genre distribution
# language distribution? to see if it is diverse enough to warrant inclusion...
# Ratings distributions - we want to only use movies that have been rated a lot

# %%
md.columns.tolist()
# Out:
# ['adult',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'homepage',
#  'id',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'video',
#  'vote_average',
#  'vote_count',
#  'general']

# %%
# Import ratings dataset
ratings = pd.read_csv('data/ratings.csv')
ratings
# Out:
#           userId  movieId  rating   timestamp
# 0              1      110     1.0  1425941529
# 1              1      147     4.5  1425942435
# 2              1      858     5.0  1425941523
# 3              1     1221     5.0  1425941546
# 4              1     1246     5.0  1425941556
# ...          ...      ...     ...         ...
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858
#
# [26024289 rows x 4 columns]

# %%
# Visualize ratings distributions
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

# %%
# Distributions of how many movies rated by each user
userID = ratings['userId'].tolist()

# %%
movies_rated = dict(Counter(userID))

# %%
movies_rated.
# Out:
# {1: 27,
#  2: 22,
#  3: 10,
#  4: 62,
#  5: 26,
#  6: 4,
#  7: 53,
#  8: 113,
#  9: 84,
#  10: 13,
#  11: 227,
#  12: 248,
#  13: 11,
#  14: 5,
#  15: 226,
#  16: 182,
#  17: 24,
#  18: 6,
#  19: 15,
#  20: 270,
#  21: 32,
#  22: 38,
#  23: 12,
#  24: 634,
#  25: 33,
#  26: 5,
#  27: 80,
#  28: 28,
#  29: 56,
#  30: 120,
#  31: 9,
#  32: 83,
#  33: 47,
#  34: 269,
#  35: 38,
#  36: 10,
#  37: 189,
#  38: 22,
#  39: 4,
#  40: 21,
#  41: 162,
#  42: 8,
#  43: 245,
#  44: 18,
#  45: 1,
#  46: 766,
#  47: 210,
#  48: 38,
#  49: 356,
#  50: 15,
#  51: 59,
#  52: 15,
#  53: 145,
#  54: 35,
#  55: 133,
#  56: 236,
#  57: 15,
#  58: 58,
#  59: 31,
#  60: 105,
#  61: 17,
#  62: 442,
#  63: 113,
#  64: 74,
#  65: 347,
#  66: 17,
#  67: 55,
#  68: 247,
#  69: 31,
#  70: 17,
#  71: 24,
#  72: 12,
#  73: 21,
#  74: 143,
#  75: 70,
#  76: 105,
#  77: 45,
#  78: 13,
#  79: 218,
#  80: 45,
#  81: 23,
#  82: 148,
#  83: 58,
#  84: 77,
#  85: 8,
#  86: 14,
#  87: 19,
#  88: 19,
#  89: 100,
#  90: 17,
# ...

# %%
# Plot the ratings distributions
user = movies_rated.keys()
rating_num = movies_rated.values()
plt.figure(figsize=(20,10))
plt.scatter(user, rating_num, s=0.5)
plt.axhline(y=200,color = 'r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
